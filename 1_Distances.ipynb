# %%
# Запустить в начале работы
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
from datetime import datetime

import pandas as pd
import numpy as np
# from gensim.models import KeyedVectors

import os

from clickhouse_driver import Client
cl_client = Client('localhost')

# %% [markdown]
# ### Данные в базе ClickHouse
#
# В базу ClickHouse данные предварительно заносятся следующие данные:
#
# - model: категория (модель адео), которую купили
# - pair: категория (модель адео), которую купил один и тот же клиент
# - distance: сколько дней прошло между покупками
#
# Пример:
#
# Клиент совершил 3 покупки:
#
# | Клиент ID | Дата       | Товары (категории) |   |   |
# |-----------|------------|--------------------|---|---|
# | 1         | 01.01.2020 | A,B                |   |   |
# | 1         | 10.01.2020 | C,D                |   |   |
# | 1         | 15.01.2020 | E,D                |   |   |
#
#
# В ClickHouse данные будут внесены следующим образом.
# Считаем расстояние в днях между покупками.
# Прошу обратить внимание, что учитывается ближайшая покупка.
# Например, товар D присутствует в 2х чеках. Расстояние считается для ближайшего чека (например, A-D - 10 дней)
#
# | Запись | model | pair | distance |  |  |
# |-|-|-|-|-|-|
# | 1 | A | B | 0 |  |  |
# | 2 | A | C | 10 |  |  |
# | 3 | A | D | 10 |  |  |
# | 4 | A | E | 15 |  |  |
# | 5 | B | A | 0 |  |  |
# | 6 | B | C | 10 |  |  |
# | 7 | B | D | 10 |  |  |
# | 8 | B | E | 15 |  |  |
# | 9 | C | A | -10 |  |  |
# | 10 | C | B | -10 |  |  |
# | 11 | C | D | 0 |  |  |
# | 12 | C | E | 5 |  |  |
# | 13 | D | A | -10 |  |  |
# | 14 | D | B | -10 |  |  |
# | 15 | D | C | 0 |  |  |
# | 16 | D | E | 0 |  |  |
# | 17 | E | A | -15 |  |  |
# | 18 | E | B | -15 |  |  |
# | 19 | E | C | -5 |  |  |
# | 20 | E | D | 0 |  |  |

# %% [markdown]
# ### Извлечение данных для анализа
#
# За год у меня получилось около 5млрд записей. Можно теперь их различным образом агрегировать.
# К сожалению, не визуализирована таблица с нужным коэффициентом, но в коде ниже показано, как он считается.
#
# В примере ниже ключевыми параметрами являются:
# - count - число покупок товаров вместе
# - quantile25 - нижний квартиль параметра distanse
# - quantile75 - верхний квартиль параметра distanse
#
# Квантили считаются в целях исключения выбросов.
# *Прошу учесть, что можно выбрать другие персентили, например 10 и 90, или 20 и 80 - это подбирается уже опытным путем, 25 и 75 показали неплохой результат.
#
# Далее комментарии в самом коде.

# %%
def load_model(model):    
    resp = cl_client.execute(
       "SELECT model, pair, count(distance), avg(distance), median(distance), stddevPop(distance), quantiles(0.25, 0.75)(distance) " \
       "FROM models " \
       "WHERE distance < 45 and distance > -45 and model=='{}' " \
       "GROUP BY model, pair " \
       "ORDER BY model, count(distance) DESC".format(model))
    df = pd.DataFrame(list(resp), columns=['model', 'pair', 'count','avg','median', 'stdev', 'quantiles'])
    
    df['quantile25'] = df['quantiles'].apply(lambda x: x[0])
    df['quantile75'] = df['quantiles'].apply(lambda x: x[1])
    
    # Считаем параметр scatter (разброс). Он говорит, какой разброс в днях между покупками товаров.  
    # Чем ниже этот параметр, тем больше тяготеет покупка одного товара к другому.  
    df['scatter'] = df['quantile75'] - df['quantile25']
    df = df.drop(columns=['quantiles'])
    df = df.merge(models, left_on='model', right_on='ModelAdeo').merge(models, left_on='pair', right_on='ModelAdeo').drop(columns=['ModelAdeo_x', 'ModelAdeo_y'])
    
    # Делим число покупок на показатель разброса. 
    # Получаем соответстующий коэффициент, который используется в дальнейшем анализе.
    df['koef'] = df['count'] / (df['scatter'] + 1)
    return df

# %%
#  Эту таблицу можно не смотреть, в ней нет нужного коэффициента.
load_model('MOD_201189')[['model_name_x', 'model_name_y', 'count', 'avg', 'median', 'stdev']].sort_values(by='count', ascending=False).head(60)
# Out:
#         model_name_x                                       model_name_y  \
# 0   Водяной радиатор                           Полипропиленовые фитинги
# 1   Водяной радиатор                                   Муфта переходная
# 2   Водяной радиатор                      Монтажные и строительные клеи
# 3   Водяной радиатор                                Крепление радиатора
# 4   Водяной радиатор                                          ППР труба
# 5   Водяной радиатор                                           Лампочка
# 6   Водяной радиатор                                  запорная арматура
# 7   Водяной радиатор                             Шуруп для гипсокартона
# 8   Водяной радиатор                                     Монтажная пена
# 9   Водяной радиатор                                           Перчатки
# 10  Водяной радиатор           Фитинги латунные для полиэтиленовых труб
# 11  Водяной радиатор                                     Силовые кабели
# 12  Водяной радиатор             Розетки и выключатели скрытая проводка
# 13  Водяной радиатор                                          Грунтовка
# 14  Водяной радиатор                                    Крепежный хомут
# 15  Водяной радиатор                         Дюбель для всех видов стен
# 16  Водяной радиатор                                       Клей-раствор
# 17  Водяной радиатор                                     Малярная кисть
# 18  Водяной радиатор                     фитинги внутренней канализации
# 19  Водяной радиатор                     Мешки для строительного мусора
# 20  Водяной радиатор                                   Водяной радиатор
# 21  Водяной радиатор                 Накладки для включателей и розеток
# 22  Водяной радиатор                                  Шуруп для металла
# 23  Водяной радиатор                                  Углы для плинтуса
# 24  Водяной радиатор  Монтажные коробки для настенных и потолочных с...
# 25  Водяной радиатор                                               Обои
# 26  Водяной радиатор                              Профиль металлический
# 27  Водяной радиатор                                           Герметик
# 28  Водяной радиатор                                Твердый уплотнитель
# 29  Водяной радиатор                           Малярные валики и бюгели
# 30  Водяной радиатор                                     Плиты гипсовые
# 31  Водяной радиатор                          Канализационная труба ПВХ
# 32  Водяной радиатор                Крепежная и соединительная пластина
# 33  Водяной радиатор                     Плинтус для напольных покрытий
# 34  Водяной радиатор                       Герметизационный уплотнитель
# 35  Водяной радиатор                          Деревянные панели и плиты
# 36  Водяной радиатор                                     Клей для обоев
# 37  Водяной радиатор                                   Салфетки, тряпки
# 38  Водяной радиатор                                     Малярная лента
# 39  Водяной радиатор    Краска для стен и потолков для внутренних работ
# 40  Водяной радиатор                                     Монтажный клей
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/client.py in execute(self, query, params, with_column_types, external_tables, query_id, settings, types_check, columnar)
#     207                     external_tables=external_tables,
#     208                     query_id=query_id, types_check=types_check,
# --> 209                     columnar=columnar
#     210                 )
#     211
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/client.py in process_ordinary_query(self, query, params, with_column_types, external_tables, query_id, types_check, columnar)
#     325                                              types_check=types_check)
#     326         return self.receive_result(with_column_types=with_column_types,
# --> 327                                    columnar=columnar)
#     328
#     329     def iter_process_ordinary_query(
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/client.py in receive_result(self, with_column_types, progress, columnar)
#      78                 gen, with_column_types=with_column_types, columnar=columnar
#      79             )
# ---> 80             return result.get_result()
#      81
#      82     def iter_receive_result(self, with_column_types=False):
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/result.py in get_result(self)
#      45         """
#      46
# ---> 47         for packet in self.packet_generator:
#      48             self.store(packet)
#      49
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/client.py in packet_generator(self)
#      90         while True:
#      91             try:
# ---> 92                 packet = self.receive_packet()
#      93                 if not packet:
#      94                     break
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/client.py in receive_packet(self)
#     104
#     105     def receive_packet(self):
# --> 106         packet = self.connection.receive_packet()
#     107
#     108         if packet.type == ServerPacketTypes.EXCEPTION:
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/connection.py in receive_packet(self)
#     383         packet = Packet()
#     384
# --> 385         packet.type = packet_type = read_varint(self.fin)
#     386
#     387         if packet_type == ServerPacketTypes.DATA:
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/reader.py in read_varint(f)
#      28
#      29     while True:
# ---> 30         i = f.read_one()
#      31         result |= (i & 0x7f) << shift
#      32         shift += 7
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/bufferedreader.py in read_one(self)
#      46     def read_one(self):
#      47         if self.position == self.current_buffer_size:
# ---> 48             self.read_into_buffer()
#      49             self.position = 0
#      50
#
# ~/personal-emailing/venv/lib/python3.7/site-packages/clickhouse_driver/bufferedreader.py in read_into_buffer(self)
#     141
#     142     def read_into_buffer(self):
# --> 143         self.current_buffer_size = self.sock.recv_into(self.buffer)
#     144
#     145         if self.current_buffer_size == 0:
#
# KeyboardInterrupt:

# %%
df = pd.concat(tmp)
df = df.merge(models, left_on='model', right_on='ModelAdeo').merge(models, left_on='pair', right_on='ModelAdeo').drop(columns=['ModelAdeo_x', 'ModelAdeo_y'])
print(df.shape)
df.head()
# Out:
# (0, 12)
# Empty DataFrame
# Columns: [model, pair, count, avg, median, std, quantile25, quantile75, scatter, art_median, Name_x, Name_y]
# Index: []

# %%
"SELECT model, pair, count(distance), avg(distance), median(distance), stddevPop(distance), quantiles(0.25, 0.75)(distance) " \
       "FROM models " \
       "WHERE distance < 45 and distance > -45 and model=='{}' " \
       "GROUP BY model, pair " \
       "ORDER BY model, count(distance) DESC".format(123)
# Out:
# "SELECT model, pair, count(distance), avg(distance), median(distance), stddevPop(distance), quantiles(0.25, 0.75)(distance) FROM models WHERE distance < 45 and distance > -45 and model=='123' GROUP BY model, pair ORDER BY model, count(distance) DESC"
